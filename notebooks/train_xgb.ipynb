# %%
import pandas as pd
import numpy as np
import datetime

# %%
def simulate_trip():
    print("Simulating trip...")

simulate_trip()
# Out:
# Simulating trip...

# %%
# %%
import matplotlib.pyplot as plt

# plot fake speed
plt.plot([0, 10, 20, 10, 0])
plt.title("Sample Speed Profile")
plt.xlabel("Time (s)")
plt.ylabel("Speed (km/h)")
plt.grid()
plt.show()
